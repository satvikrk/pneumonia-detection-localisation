# %% [markdown]
# # RSNA Pneumonia Localization (Weakly Supervised CAM Approach)
#
# This notebook reproduces the *Weakly Supervised Pneumonia Localization* method from the research paper (our ML assignment).
# It combines:
# - A **CNN classifier** to predict pneumonia vs normal.
# - A **Class Activation Map (CAM)** to highlight the pneumonia region.
# - A **clustering + bounding box** method to localize the infected area.
# - Evaluation using **Intersection over Union (IoU)** metric.
#
# We’ll use a **small subset** of the RSNA Pneumonia dataset for fast computation.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Step 1 — Install Dependencies
#
# This installs any required Python libraries like PyTorch, OpenCV, and pydicom (for reading `.dcm` medical images).
# Run this once — skip if already installed.

# %%
# !pip install pydicom
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydicom in /Users/satvik/Library/Python/3.12/lib/python/site-packages (3.0.1)

# %% [markdown]
# ## Step 2 — Unzip and Explore Dataset
#
# We unzip the RSNA Pneumonia Detection dataset from Google Drive and inspect its structure.
# The dataset contains:
# - **stage_2_train_images/** → chest X-ray images in DICOM format.
# - **stage_2_train_labels.csv** → bounding box coordinates and labels.

# %%
import os
import zipfile
from pathlib import Path

# Project root = current working directory (VS Code notebook/script)
PROJECT_ROOT = Path(os.getcwd()).resolve()

# Default local dataset folder (you already use this structure)
DATA_DIR = PROJECT_ROOT / "rsna-pneumonia-detection-challenge"

# Optional: path to a zip on local disk (leave as None if already extracted)
# Example for local: "/Users/you/Downloads/rsna-pneumonia-detection-challenge.zip"
# Example for Colab Drive: "/content/drive/MyDrive/ML ASSIGNMENT/rsna-pneumonia-detection-challenge (1).zip"
ZIP_PATH = None  # set to a string path if you want auto-extract
EXTRACT_TO = DATA_DIR  # where to extract if ZIP_PATH is provided

print("Project root:", PROJECT_ROOT)
print("Dataset dir:", DATA_DIR)

# If a ZIP path is provided and dataset dir doesn't exist, extract it
if ZIP_PATH is not None:
    ZIP_PATH = Path(ZIP_PATH).expanduser()
    if not EXTRACT_TO.exists():
        if not ZIP_PATH.exists():
            raise FileNotFoundError(f"ZIP not found at {ZIP_PATH}")
        print(f"Unzipping dataset to {EXTRACT_TO} ...")
        EXTRACT_TO.parent.mkdir(parents=True, exist_ok=True)
        with zipfile.ZipFile(ZIP_PATH, 'r') as z:
            z.extractall(str(EXTRACT_TO))
        print("Done unzipping.")
    else:
        print("Dataset already present at", EXTRACT_TO)
else:
    print("ZIP_PATH not set; assuming dataset already exists at", EXTRACT_TO)

# Important expected paths
TRAIN_LABELS = DATA_DIR / "stage_2_train_labels.csv"
CLASS_INFO   = DATA_DIR / "stage_2_detailed_class_info.csv"
SAMPLE_SUB   = DATA_DIR / "stage_2_sample_submission.csv"
TRAIN_IMG_DIR = DATA_DIR / "stage_2_train_images"
TEST_IMG_DIR  = DATA_DIR / "stage_2_test_images"

print("Expected CSVs and directories:")
print("  TRAIN_LABELS:", TRAIN_LABELS, "exists?", TRAIN_LABELS.exists())
print("  CLASS_INFO  :", CLASS_INFO, "exists?", CLASS_INFO.exists())
print("  SAMPLE_SUB  :", SAMPLE_SUB, "exists?", SAMPLE_SUB.exists())
print("  TRAIN_IMG_DIR:", TRAIN_IMG_DIR, "exists?", TRAIN_IMG_DIR.exists())
print("  TEST_IMG_DIR :", TEST_IMG_DIR, "exists?", TEST_IMG_DIR.exists())

# Show top-level contents for a quick sanity check
if DATA_DIR.exists():
    top_dirs = [p.name for p in DATA_DIR.iterdir() if p.is_dir()]
    top_files = [p.name for p in DATA_DIR.iterdir() if p.is_file()]
    print("Top-level dirs:", top_dirs[:10])
    print("Top-level files:", top_files[:10])
else:
    raise FileNotFoundError(f"Dataset directory missing at {DATA_DIR}. Set ZIP_PATH to extract or adjust DATA_DIR.")
# Out:
# Project root: /Users/satvik/Documents/transfer/Year3/Sem5/ML/Project/Code/Weakly-Supervised-Pneumonia-Localization-master
# Dataset dir: /Users/satvik/Documents/transfer/Year3/Sem5/ML/Project/Code/Weakly-Supervised-Pneumonia-Localization-master/rsna-pneumonia-detection-challenge
# ZIP_PATH not set; assuming dataset already exists at /Users/satvik/Documents/transfer/Year3/Sem5/ML/Project/Code/Weakly-Supervised-Pneumonia-Localization-master/rsna-pneumonia-detection-challenge
# Expected CSVs and directories:
#   TRAIN_LABELS: /Users/satvik/Documents/transfer/Year3/Sem5/ML/Project/Code/Weakly-Supervised-Pneumonia-Localization-master/rsna-pneumonia-detection-challenge/stage_2_train_labels.csv exists? True
#   CLASS_INFO  : /Users/satvik/Documents/transfer/Year3/Sem5/ML/Project/Code/Weakly-Supervised-Pneumonia-Localization-master/rsna-pneumonia-detection-challenge/stage_2_detailed_class_info.csv exists? True
#   SAMPLE_SUB  : /Users/satvik/Documents/transfer/Year3/Sem5/ML/Project/Code/Weakly-Supervised-Pneumonia-Localization-master/rsna-pneumonia-detection-challenge/stage_2_sample_submission.csv exists? True
#   TRAIN_IMG_DIR: /Users/satvik/Documents/transfer/Year3/Sem5/ML/Project/Code/Weakly-Supervised-Pneumonia-Localization-master/rsna-pneumonia-detection-challenge/stage_2_train_images exists? True
#   TEST_IMG_DIR : /Users/satvik/Documents/transfer/Year3/Sem5/ML/Project/Code/Weakly-Supervised-Pneumonia-Localization-master/rsna-pneumonia-detection-challenge/stage_2_test_images exists? True
# Top-level dirs: ['stage_2_test_images', 'stage_2_train_images']
# Top-level files: ['.DS_Store', 'stage_2_detailed_class_info.csv', 'stage_2_sample_submission.csv', 'GCP Credits Request Link - RSNA.txt', 'stage_2_train_labels.csv']

# %% [markdown]
# ## Step 3 — Import Libraries
#
# Here we import all essential libraries for:
# - Image processing (`cv2`, `pydicom`, `numpy`)
# - Data handling (`pandas`)
# - Deep learning (`torch`, `torchvision`)
# - Visualization (`matplotlib`)

# %%
import pydicom
import numpy as np
import cv2
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

print("Imports done.")
# Out:
# Imports done.

# %% [markdown]
# ## Step 4 — Load and Explore CSV Labels
#
# We load the CSV file containing pneumonia annotations:
# - Each image (patientId) can have 0 or more bounding boxes.
# - `Target = 1` means pneumonia is present (box provided).
# - `Target = 0` means no pneumonia (no bounding box).
#
# We also group by patient ID to easily retrieve annotations later.

# %%
CSV_PATH = os.path.join(EXTRACT_TO, "stage_2_train_labels.csv")
df = pd.read_csv(CSV_PATH)
print("CSV rows:", len(df))
print(df.head())

# CSV columns: patientId, x, y, width, height, Target
# Target = 1 means pneumonia box present; 0 typically indicates no box (image-level negative)
# group boxes by patientId for easy lookup
grouped = df.groupby("patientId")
print("Unique patient IDs:", df['patientId'].nunique())
# Out:
# CSV rows: 30227
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
# Unique patient IDs: 26684

# %% [markdown]
# ## Step 5 — DICOM to Image Conversion
#
# This function:
# - Reads `.dcm` medical images.
# - Normalizes pixel values (0–255 range).
# - Converts grayscale to RGB.
# - Resizes to `128×128` for faster training.
#
# We also test one sample image to confirm it works.

# %%
def read_dicom_as_image(path, target_size=(128,128)):
    ds = pydicom.dcmread(path)
    arr = ds.pixel_array.astype(np.float32)
    # normalize to 0-255
    arr -= arr.min()
    if arr.max() > 0:
        arr = arr / arr.max()
    arr = (arr * 255).astype(np.uint8)
    # convert to 3-channel
    img = cv2.cvtColor(arr, cv2.COLOR_GRAY2BGR)
    img = cv2.resize(img, target_size)
    return img

# quick test
example_imgname = df['patientId'].iloc[0]
example_path = os.path.join(EXTRACT_TO, "stage_2_train_images", example_imgname + ".dcm")
print("Example path exists:", os.path.exists(example_path))
img = read_dicom_as_image(example_path)
print("Image shape:", img.shape)
plt.imshow(img, cmap='gray'); plt.title("Example"); plt.axis('off')
# Out:
# Example path exists: True
# Image shape: (128, 128, 3)
# (np.float64(-0.5), np.float64(127.5), np.float64(127.5), np.float64(-0.5))

# %% [markdown]
# ## Step 6 — Custom Dataset Class
#
# This dataset class handles:
# - Loading image tensors.
# - Assigning pneumonia labels (`1` = positive, `0` = negative).
# - Scaling bounding boxes to match the resized 128×128 images.
#
# It also returns ground truth boxes for IoU comparison later.

# %%
import pydicom
import numpy as np
import cv2
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

class RSNADataset(Dataset):
    def __init__(self, csv_df, images_dir, ids_list, transform=None):
        self.df = csv_df
        self.images_dir = images_dir
        self.ids = ids_list
        self.transform = transform

        # mapping id -> list of boxes
        self.boxes = {}
        for pid, group in self.df.groupby("patientId"):
            boxes = []
            for _, r in group.iterrows():
                if r['Target'] == 1:
                    x, y, w, h = r['x'], r['y'], r['width'], r['height']
                    boxes.append([x, y, w, h])
            if len(boxes) > 0:
                self.boxes[pid] = boxes

    def __len__(self):
        return len(self.ids)

    def __getitem__(self, idx):
        pid = self.ids[idx]
        dcm_path = os.path.join(self.images_dir, pid + ".dcm")
        img = read_dicom_as_image(dcm_path, target_size=(128,128))

        # label: 1 if has pneumonia annotation in CSV, else 0
        label = 1 if pid in self.boxes else 0

        # normalized float32 tensor (C,H,W) for PyTorch
        img_float = img.astype(np.float32) / 255.0
        img_t = torch.tensor(img_float).permute(2,0,1).float()

        # --- FIX STARTS HERE ---
        if pid in self.boxes:
            # original boxes were in original DICOM pixel coords; we need to scale them to 128x128
            ds = pydicom.dcmread(dcm_path)
            orig_h, orig_w = ds.pixel_array.shape
            hx, hy = 128.0 / orig_w, 128.0 / orig_h
            gt_boxes_resized = []
            for (x, y, w, h) in self.boxes[pid]:
                x1 = int(x * hx); y1 = int(y * hy)
                x2 = int((x + w) * hx); y2 = int((y + h) * hy)
                gt_boxes_resized.append([x1, y1, x2, y2])
        else:
            gt_boxes_resized = []   # ✅ FIX: empty list instead of None
        # --- FIX ENDS HERE ---

        return img_t, label, pid, gt_boxes_resized

def custom_collate_fn(batch):
    """
    Custom collate function to handle different number of bounding boxes
    and potential None values for ground truth boxes.
    """
    imgs = torch.stack([item[0] for item in batch])
    labels = torch.tensor([item[1] for item in batch])
    pids = [item[2] for item in batch]
    gt_boxes_resized = [item[3] for item in batch]  # now always a list, never None

    return imgs, labels, pids, gt_boxes_resized

print("✅ Dataset class fixed and ready. Empty lists used instead of None.")
# Out:
# ✅ Dataset class fixed and ready. Empty lists used instead of None.

# %% [markdown]
# ## Step 7 — Create Subset and DataLoaders
#
# We use only a **small subset** of the dataset (e.g., 80 images) for quick runs.
# Images are split into **training** and **validation** sets.
#
# `DataLoader` helps batch and shuffle data efficiently during training.

# %%
# SETTINGS: small subset for speed
SUBSET_SIZE = 10000   # total images to use (you can reduce to 40 if very slow)
VAL_FRACTION = 0.2
random.seed(42)

all_ids = df['patientId'].unique().tolist()
print("Total images available:", len(all_ids))

# sample a subset
subset_ids = random.sample(all_ids, SUBSET_SIZE)
train_ids, val_ids = train_test_split(subset_ids, test_size=VAL_FRACTION, random_state=42)

train_ds = RSNADataset(df, os.path.join(EXTRACT_TO, "stage_2_train_images"), train_ids)
val_ds   = RSNADataset(df, os.path.join(EXTRACT_TO, "stage_2_train_images"), val_ids)

print("Train size:", len(train_ds), "Val size:", len(val_ds))
train_loader = DataLoader(train_ds, batch_size=8, shuffle=True, collate_fn=custom_collate_fn)
val_loader = DataLoader(val_ds, batch_size=8, shuffle=False, collate_fn=custom_collate_fn)
# Out:
# Total images available: 26684
# Train size: 8000 Val size: 2000

# %% [markdown]
# ## Step 8 — Build CNN Model (CAM-Compatible)
#
# This is a lightweight CNN architecture similar to the paper’s 10-layer design but smaller for speed.
# It ends with:
# - A **Global Average Pooling (GAP)** layer.
# - A **Fully Connected (FC)** layer with 2 outputs (Pneumonia / Normal).
#
# This structure allows **Class Activation Maps (CAMs)** to be extracted later.

# %%
class SmallCAMNet(nn.Module):
    def __init__(self, n_classes=2):
        super().__init__()
        # feature extractor (final conv outputs channels = 64)
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1), nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, padding=1), nn.ReLU()
            # final conv output: (batch,64,32,32) given 128x128 input after two pools
        )
        # global average pool -> fc
        self.gap = nn.AdaptiveAvgPool2d(1)  # produces (batch,64,1,1)
        self.fc = nn.Linear(64, n_classes)

    def forward(self, x):
        feat = self.features(x)
        gap = self.gap(feat).view(feat.size(0), -1)
        out = self.fc(gap)
        return out, feat

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SmallCAMNet(n_classes=2).to(device)
print("Model created on", device)
# Out:
# Model created on cpu

# %% [markdown]
# ## Step 9 — Train the Model (Quick Training)
#
# We train for only a few epochs on the subset using:
# - **Adam optimizer**
# - **CrossEntropyLoss**
#
# This is enough to demonstrate classification and generate meaningful CAMs.
# Print statements show batch-wise progress and accuracy updates.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()

EPOCHS = 20   # small so it runs quickly; increase if you have time
for epoch in range(EPOCHS):
    model.train()
    running_loss = 0.0
    total = 0; correct = 0
    for i, (imgs, labels, pids, _) in enumerate(train_loader):
        imgs = imgs.to(device); labels = labels.to(device)
        optimizer.zero_grad()
        outputs, _ = model(imgs)
        loss = criterion(outputs, labels)
        loss.backward(); optimizer.step()
        running_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        total += labels.size(0); correct += (preds == labels).sum().item()
        if i % 5 == 0:
            print(f"Epoch {epoch+1} batch {i} loss {loss.item():.4f} acc {correct/total:.3f}")
    print(f"Epoch {epoch+1} completed. Avg loss: {running_loss/(i+1):.4f}, Train acc: {correct/total:.3f}")
    # quick validation
    model.eval()
    v_total=0; v_correct=0
    with torch.no_grad():
        for imgs, labels, pids, _ in val_loader:
            imgs = imgs.to(device); labels = labels.to(device)
            outputs, _ = model(imgs)
            _, preds = torch.max(outputs, 1)
            v_total += labels.size(0); v_correct += (preds == labels).sum().item()
    print(f"Validation acc after epoch {epoch+1}: {v_correct/v_total:.3f}")
print("Training done.")
# Out:
# Epoch 1 batch 0 loss 0.6924 acc 0.500
# Epoch 1 batch 5 loss 0.7035 acc 0.250
# Epoch 1 batch 10 loss 0.6646 acc 0.466
# Epoch 1 batch 15 loss 0.6777 acc 0.578
# Epoch 1 batch 20 loss 0.6372 acc 0.619
# Epoch 1 batch 25 loss 0.6077 acc 0.639
# Epoch 1 batch 30 loss 0.5787 acc 0.673
# Epoch 1 batch 35 loss 0.5768 acc 0.670
# Epoch 1 batch 40 loss 0.4547 acc 0.686
# Epoch 1 batch 45 loss 0.6677 acc 0.685
# Epoch 1 batch 50 loss 0.2860 acc 0.699
# Epoch 1 batch 55 loss 0.5683 acc 0.703
# Epoch 1 batch 60 loss 0.2446 acc 0.705
# Epoch 1 batch 65 loss 0.5576 acc 0.710
# Epoch 1 batch 70 loss 0.5548 acc 0.710
# Epoch 1 batch 75 loss 0.5651 acc 0.717
# Epoch 1 batch 80 loss 0.5580 acc 0.721
# Epoch 1 batch 85 loss 0.4040 acc 0.721
# Epoch 1 batch 90 loss 0.4168 acc 0.725
# Epoch 1 batch 95 loss 0.4308 acc 0.725
# Epoch 1 batch 100 loss 0.5601 acc 0.725
# Epoch 1 batch 105 loss 0.4490 acc 0.728
# Epoch 1 batch 110 loss 0.3983 acc 0.730
# Epoch 1 batch 115 loss 0.4111 acc 0.737
# Epoch 1 batch 120 loss 0.9630 acc 0.733
# Epoch 1 batch 125 loss 0.8425 acc 0.732
# Epoch 1 batch 130 loss 0.5501 acc 0.733
# Epoch 1 batch 135 loss 0.5549 acc 0.732
# Epoch 1 batch 140 loss 0.4487 acc 0.732
# Epoch 1 batch 145 loss 0.7011 acc 0.737
# Epoch 1 batch 150 loss 0.7217 acc 0.738
# Epoch 1 batch 155 loss 0.5756 acc 0.740
# Epoch 1 batch 160 loss 0.3986 acc 0.743
# Epoch 20 batch 900 loss 0.3654 acc 0.808
# Epoch 20 batch 905 loss 0.2501 acc 0.808
# Epoch 20 batch 910 loss 0.5742 acc 0.807
# Epoch 20 batch 915 loss 0.2296 acc 0.808
# Epoch 20 batch 920 loss 0.4237 acc 0.807
# Epoch 20 batch 925 loss 0.4906 acc 0.807
# Epoch 20 batch 930 loss 0.3020 acc 0.807
# Epoch 20 batch 935 loss 0.1460 acc 0.808
# Epoch 20 batch 940 loss 0.3388 acc 0.808
# Epoch 20 batch 945 loss 0.5973 acc 0.807
# Epoch 20 batch 950 loss 0.3184 acc 0.807
# Epoch 20 batch 955 loss 0.1680 acc 0.807
# Epoch 20 batch 960 loss 0.8384 acc 0.807
# Epoch 20 batch 965 loss 0.2481 acc 0.808
# Epoch 20 batch 970 loss 0.2410 acc 0.808
# Epoch 20 batch 975 loss 0.3188 acc 0.808
# Epoch 20 batch 980 loss 0.6777 acc 0.808
# Epoch 20 batch 985 loss 0.1764 acc 0.809
# Epoch 20 batch 990 loss 0.9561 acc 0.808
# Epoch 20 batch 995 loss 0.4544 acc 0.808
# Epoch 20 completed. Avg loss: 0.4281, Train acc: 0.807
# Validation acc after epoch 20: 0.794
# Training done.

# %% [markdown]
# ## Step 10 — Generate Class Activation Maps (CAM)
#
# The CAM highlights which areas of the X-ray image influenced the “Pneumonia” prediction.
# We:
# 1. Extract the last convolutional layer features.
# 2. Weight them using the FC layer’s pneumonia class weights.
# 3. Combine and normalize them into a heatmap.
#
# Higher intensity = higher pneumonia probability region.

# %%
def generate_cam_for_tensor(model, input_tensor, class_idx=1):
    """
    input_tensor: 1 x C x H x W (torch tensor on device)
    class_idx: target class index (1 = pneumonia for our labeling)
    returns: cam_resized (H,W) normalized 0-1
    """
    model.eval()
    with torch.no_grad():
        outputs, features = model(input_tensor)
        # get fc weights (shape: n_classes x n_features)
        fc_w = model.fc.weight.data.cpu().numpy()  # shape (2,64)
        # features shape: 1 x C x h x w
        feat = features[0].cpu().numpy()  # (C, h, w)
        cams = np.zeros((feat.shape[1], feat.shape[2]), dtype=np.float32)
        # compute weighted sum of feature maps
        for k in range(feat.shape[0]):
            cams += fc_w[class_idx, k] * feat[k, :, :]
        # relu
        cams = np.maximum(cams, 0)
        # normalize
        if cams.max() > 0:
            cams = cams / (cams.max() + 1e-8)
        # resize to input size
        _, _, H, W = input_tensor.shape
        cam_resized = cv2.resize(cams, (W, H))
        return cam_resized

print("CAM function ready.")
# Out:
# CAM function ready.

# %% [markdown]
# ## Step 11 — CAM to Bounding Boxes (DFS-like Clustering)
#
# We convert the CAM into regions by:
# - Thresholding (using `mean + std/2` as a cutoff).
# - Grouping connected bright regions (like DFS clustering).
# - Drawing bounding boxes around each region.
#
# These boxes represent **predicted pneumonia locations**.

# %%
def cam_to_bboxes(cam, threshold=None, min_area=50):
    """
    cam: 2D normalized 0-1
    threshold: if None, use mean + std heuristic
    returns: list of bounding boxes [x1,y1,x2,y2] in cam coordinates (same size)
    """
    if threshold is None:
        threshold = cam.mean() + cam.std()*0.5
    mask = (cam > threshold).astype(np.uint8)
    # morphological closing to join small holes
    kernel = np.ones((3,3), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=1)
    num_labels, labels_im = cv2.connectedComponents(mask)
    bboxes = []
    for lbl in range(1, num_labels):
        ys, xs = np.where(labels_im == lbl)
        if len(xs) == 0:
            continue
        x1, x2 = xs.min(), xs.max()
        y1, y2 = ys.min(), ys.max()
        area = (x2-x1)*(y2-y1)
        if area >= min_area:
            bboxes.append([int(x1), int(y1), int(x2), int(y2)])
    return bboxes

print("Bbox extraction ready.")
# Out:
# Bbox extraction ready.

# %% [markdown]
# ## Step 12 — IoU (Intersection over Union) Function
#
# The IoU measures how much the **predicted** bounding box overlaps with the **ground truth**.
# \[
# IoU = \frac{Area\ of\ Overlap}{Area\ of\ Union}
# \]
#
# A higher IoU means better localization accuracy.

# %%
def iou_box(boxA, boxB):
    """
    box = [x1,y1,x2,y2]
    returns IoU float
    """
    if boxA is None or boxB is None:
        return 0.0
    ax1, ay1, ax2, ay2 = boxA
    bx1, by1, bx2, by2 = boxB
    inter_x1 = max(ax1, bx1); inter_y1 = max(ay1, by1)
    inter_x2 = min(ax2, bx2); inter_y2 = min(ay2, by2)
    iw = max(0, inter_x2 - inter_x1 + 1)
    ih = max(0, inter_y2 - inter_y1 + 1)
    inter_area = iw * ih
    areaA = (ax2 - ax1 + 1) * (ay2 - ay1 + 1)
    areaB = (bx2 - bx1 + 1) * (by2 - by1 + 1)
    denom = areaA + areaB - inter_area
    if denom <= 0:
        return 0.0
    return inter_area / float(denom)

print("IoU function ready.")
# Out:
# IoU function ready.

# %% [markdown]
# ## Step 13 — Evaluate Model and Visualize Results
#
# For each validation image:
# - Generate the CAM.
# - Extract bounding boxes.
# - Compare with ground truth boxes using IoU.
#
# We print:
# - CAM statistics (mean, std, threshold used)
# - Predicted vs ground truth boxes
# - IoU scores
#
# We also visualize sample images with:
# - **Red boxes = Ground Truth**
# - **Blue boxes = Predicted (CAM regions)**
# - **Color overlay = Heatmap**

# %%
print("Evaluating on validation set (subset) ...")
model.eval()

all_ious = []
count = 0
pid_list = []  # <-- new: to store PIDs for table
with torch.no_grad():
    for imgs, labels, pids, gt_boxes in val_loader:
        for b in range(imgs.size(0)):
            img = imgs[b].unsqueeze(0).to(device)
            label = int(labels[b].item())
            pid = pids[b]
            print(f"\nProcessing PID {pid} | label = {label}")
            cam = generate_cam_for_tensor(model, img, class_idx=1)
            print("  CAM min/max/mean/std:", cam.min(), cam.max(), cam.mean(), cam.std())
            # adaptive thresholding
            threshold = cam.mean() + cam.std()*0.5
            print("  Using threshold:", threshold)
            bboxes = cam_to_bboxes(cam, threshold=threshold, min_area=25)
            print("  Predicted boxes (count):", len(bboxes), bboxes)
            # get ground truth box (if any)
            gt_list = gt_boxes[b]  # this is the resized gt boxes list or None
            if gt_list is None:
                print("  No ground truth box for this image (negative). Skipping IoU -> append 0.")
                all_ious.append(0.0)
                pid_list.append((pid, 0.0))
            else:
                # if multiple GT boxes, compare to each predicted box and take max IoU
                best_iou_for_image = 0.0
                for gt in gt_list:
                    for pred in bboxes:
                        iou_val = iou_box(pred, gt)
                        if iou_val > best_iou_for_image:
                            best_iou_for_image = iou_val
                print("  Best IoU for this image:", best_iou_for_image)
                all_ious.append(best_iou_for_image)
                pid_list.append((pid, best_iou_for_image))
            # show visualization for first few images
            if count < 6:
                import matplotlib.pyplot as plt
                npimg = (img[0].cpu().permute(1,2,0).numpy()*255).astype(np.uint8)
                vis = npimg.copy()
                # draw predicted boxes in blue
                for pb in bboxes:
                    cv2.rectangle(vis, (pb[0], pb[1]), (pb[2], pb[3]), (255,0,0), 2)
                # draw GT boxes in red
                if gt_list is not None:
                    for gt in gt_list:
                        cv2.rectangle(vis, (gt[0], gt[1]), (gt[2], gt[3]), (0,0,255), 2)
                # overlay heatmap
                heatmap = (cam * 255).astype(np.uint8)
                heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
                heatmap = cv2.resize(heatmap, (vis.shape[1], vis.shape[0]))
                overlay = cv2.addWeighted(vis, 0.6, heatmap, 0.4, 0)
                plt.figure(figsize=(6,6)); plt.imshow(overlay[:,:,::-1]); plt.title(f"PID {pid} overlay"); plt.axis('off')
                plt.show()
            count += 1

import numpy as np
mean_iou = float(np.mean(all_ious))
print("\n=== Results ===")
print("Evaluated images:", len(all_ious))
print("Mean IoU (subset):", mean_iou)
print("IoU list (first 20):", all_ious[:20])

# ---------- NEW: Neat Table Print ----------
print("\n=== Detailed IoU Table ===")
print(f"{'Index':<6} {'PID':<40} {'IoU':>8}")
print("-"*58)
for idx, (pid, iou_val) in enumerate(pid_list):
    print(f"{idx+1:<6} {pid:<40} {iou_val:>8.4f}")
print("-"*58)
print(f"{'Mean IoU':<46} {mean_iou:>8.4f}")
print("===========================================")
# Out:
# Evaluating on validation set (subset) ...
#
# Processing PID 646917f3-2303-43ef-acac-37470021e91f | label = 1
#   CAM min/max/mean/std: 0.0 0.99927574 0.23675448 0.30552033
#   Using threshold: 0.38951463
#   Predicted boxes (count): 6 [[51, 0, 83, 8], [107, 9, 121, 23], [5, 23, 17, 33], [13, 41, 22, 56], [32, 58, 103, 127], [113, 81, 123, 94]]
#   Best IoU for this image: 0.02154328241284763
# Processing PID 943b27f1-ba1c-415b-b738-7b52aefa445b | label = 0
#   CAM min/max/mean/std: 0.0 0.99935997 0.28631556 0.3436297
#   Using threshold: 0.45813042
#   Predicted boxes (count): 4 [[0, 0, 11, 10], [17, 4, 102, 127], [91, 15, 112, 33], [13, 20, 27, 44]]
#   Best IoU for this image: 0.0
# Processing PID 42bfb1f3-9f7e-4e47-8983-49b16d73697f | label = 0
#   CAM min/max/mean/std: 0.0 0.97560257 0.17274249 0.23814236
#   Using threshold: 0.29181367
#   Predicted boxes (count): 6 [[44, 0, 77, 8], [92, 5, 113, 24], [2, 12, 12, 18], [12, 30, 19, 50], [101, 33, 111, 66], [22, 63, 105, 127]]
#   Best IoU for this image: 0.0
# Processing PID 6c14d1da-5519-4205-a97a-79950670c257 | label = 0
#   CAM min/max/mean/std: 0.0 0.96765494 0.16886696 0.26206815
#   Using threshold: 0.29990104
#   Predicted boxes (count): 7 [[46, 0, 71, 16], [104, 0, 121, 19], [0, 14, 8, 20], [112, 26, 115, 36], [12, 33, 20, 58], [80, 35, 93, 47], [22, 61, 107, 127]]
#   Best IoU for this image: 0.0
# Processing PID 05083068-f4df-464a-b669-3c084ee05f1f | label = 1
#   CAM min/max/mean/std: 0.0 0.9835345 0.21652715 0.28787535
#   Using threshold: 0.3604648
#   Predicted boxes (count): 5 [[59, 0, 66, 15], [103, 0, 123, 19], [12, 5, 23, 13], [24, 23, 29, 31], [27, 48, 90, 127]]
#   Best IoU for this image: 0.026545316647705725
# Processing PID dd48746a-162b-41da-8248-8adcaaa87080 | label = 0
#   CAM min/max/mean/std: 0.0 0.9791539 0.17933588 0.24939156
#   Using threshold: 0.30403167
#   Predicted boxes (count): 3 [[0, 0, 127, 16], [18, 54, 92, 127], [112, 57, 127, 73]]
#   Best IoU for this image: 0.0
# Processing PID b18e4375-e20d-42e9-a545-a62294135c07 | label = 1
#   CAM min/max/mean/std: 0.0 0.97424686 0.11709568 0.16817488
#   Using threshold: 0.20118311
#   Predicted boxes (count): 7 [[0, 0, 55, 92], [91, 0, 119, 18], [61, 6, 75, 48], [118, 25, 125, 34], [105, 38, 111, 76], [17, 73, 107, 127], [0, 121, 5, 127]]
#   Best IoU for this image: 0.17902097902097902
#
# Processing PID 5d9a916a-ddc0-4821-948b-7a9b16e3a31a | label = 0
#   CAM min/max/mean/std: 0.0 0.99893504 0.2775704 0.36185762
#   Using threshold: 0.4584992
#   Predicted boxes (count): 4 [[50, 8, 70, 20], [107, 20, 115, 49], [12, 24, 19, 42], [12, 52, 115, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID d1425230-2b69-4a98-9a98-ceb29b40e039 | label = 0
#   CAM min/max/mean/std: 0.0 0.9799696 0.12208608 0.14021805
#   Using threshold: 0.1921951
#   Predicted boxes (count): 3 [[87, 0, 127, 17], [0, 5, 15, 27], [17, 62, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 06ce1fa2-986b-4936-82f5-7b06d0d3b4ff | label = 0
#   CAM min/max/mean/std: 0.0 0.98521423 0.16956308 0.2292159
#   Using threshold: 0.28417104
#   Predicted boxes (count): 8 [[0, 0, 66, 14], [79, 0, 127, 16], [12, 17, 21, 54], [95, 19, 114, 49], [16, 64, 90, 127], [117, 74, 127, 99], [97, 87, 108, 116], [0, 90, 12, 110]]
#   Best IoU for this image: 0.0
#
# Processing PID 60370334-2b17-4c9d-a05b-b5746bdaa3b1 | label = 1
#   CAM min/max/mean/std: 0.0 0.97380656 0.29074174 0.27150232
#   Using threshold: 0.4264929
#   Predicted boxes (count): 9 [[36, 0, 52, 3], [78, 0, 92, 7], [40, 4, 74, 44], [0, 19, 33, 35], [78, 37, 94, 47], [14, 41, 35, 60], [103, 65, 124, 102], [29, 66, 90, 127], [4, 107, 13, 123]]
#   Best IoU for this image: 0.048116089613034624
#
# Processing PID 30258414-64e5-43d9-94bf-b6e175b91542 | label = 0
#   CAM min/max/mean/std: 0.0 0.9707524 0.12038769 0.18840353
#   Using threshold: 0.21458945
#   Predicted boxes (count): 6 [[45, 0, 71, 11], [105, 10, 115, 30], [12, 22, 18, 35], [0, 58, 123, 127], [6, 80, 19, 93], [104, 86, 110, 92]]
#   Best IoU for this image: 0.0
#
# Processing PID c72e8368-e692-4ce6-add7-5c7dd27eae3e | label = 0
#   CAM min/max/mean/std: 0.0 0.9984967 0.18263832 0.29596275
#   Using threshold: 0.3306197
#   Predicted boxes (count): 4 [[33, 0, 69, 14], [80, 0, 102, 15], [112, 0, 127, 11], [17, 61, 106, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID d5be0945-b546-4640-b0a0-d2dd209122e8 | label = 1
#   CAM min/max/mean/std: 0.0 0.97690755 0.31872752 0.26769564
#   Using threshold: 0.45257533
#   Predicted boxes (count): 5 [[71, 0, 82, 4], [3, 16, 9, 23], [106, 17, 123, 33], [16, 48, 94, 127], [115, 81, 127, 127]]
#   Best IoU for this image: 0.056962025316455694
#
# Processing PID d4653287-cdac-4e8b-94db-b3c71147faf4 | label = 1
#   CAM min/max/mean/std: 0.0 0.99974936 0.41257334 0.3206948
#   Using threshold: 0.57292074
#   Predicted boxes (count): 6 [[57, 0, 64, 5], [76, 0, 88, 6], [117, 15, 123, 26], [25, 38, 96, 127], [115, 45, 127, 59], [3, 71, 6, 81]]
#   Best IoU for this image: 0.16545083163116428
#
# Processing PID 2f9c1b97-74a7-4781-bad3-c46cc08c69c8 | label = 1
#   CAM min/max/mean/std: 0.0 0.9994977 0.47894958 0.3539315
#   Using threshold: 0.6559153
#   Predicted boxes (count): 1 [[13, 10, 113, 125]]
#   Best IoU for this image: 0.04096961420279959
#
# Processing PID 18536f77-096d-4d43-8bd2-3fdf65c9969a | label = 0
#   CAM min/max/mean/std: 0.0 0.99943924 0.30017307 0.33988798
#   Using threshold: 0.47011706
#   Predicted boxes (count): 4 [[26, 0, 52, 15], [115, 2, 119, 10], [42, 8, 117, 127], [12, 31, 45, 70]]
#   Best IoU for this image: 0.0
#
# Processing PID 7d11c6df-ddcc-4a87-b534-e627c5670702 | label = 0
#   CAM min/max/mean/std: 0.0 0.9988458 0.3255758 0.32672676
#   Using threshold: 0.48893917
#   Predicted boxes (count): 3 [[20, 7, 105, 127], [0, 8, 11, 22], [0, 39, 2, 81]]
#   Best IoU for this image: 0.0
#
# Processing PID f98a1305-2906-4fee-87b1-f641370fd548 | label = 0
#   CAM min/max/mean/std: 0.0 0.9752524 0.12604636 0.15439728
#   Using threshold: 0.203245
#   Predicted boxes (count): 9 [[14, 0, 30, 6], [48, 0, 123, 21], [90, 41, 104, 85], [17, 43, 31, 81], [110, 55, 127, 77], [36, 77, 82, 122], [120, 86, 122, 107], [117, 111, 124, 127], [59, 121, 70, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID ac282951-7cd1-4e12-9a60-d11351383af6 | label = 0
#   CAM min/max/mean/std: 0.0 0.99960494 0.24990016 0.33827528
#   Using threshold: 0.41903782
#   Predicted boxes (count): 4 [[114, 7, 127, 22], [0, 17, 10, 23], [12, 33, 20, 72], [18, 59, 110, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 9a2b8b68-b1fe-40ba-9422-fe8278b5f315 | label = 0
#   CAM min/max/mean/std: 0.0 0.97867405 0.23970434 0.27156866
#   Using threshold: 0.37548867
#   Predicted boxes (count): 6 [[25, 0, 43, 9], [86, 0, 127, 69], [0, 8, 13, 19], [43, 10, 49, 22], [20, 57, 86, 127], [112, 79, 127, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 1851dff6-31ec-4453-9ddc-95c0aedace5b | label = 1
#   CAM min/max/mean/std: 0.0 0.96031255 0.3166444 0.21005727
#   Using threshold: 0.42167303
#   Predicted boxes (count): 2 [[111, 0, 124, 12], [14, 9, 93, 124]]
#   Best IoU for this image: 0.21941830624465355
#
# Processing PID 9560b299-0367-42d7-b627-32a7212015f0 | label = 0
#   CAM min/max/mean/std: 0.0 0.96824616 0.29919708 0.26066163
#   Using threshold: 0.42952788
#   Predicted boxes (count): 2 [[0, 0, 16, 11], [14, 21, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 3999dbf4-b2a0-45b9-9ee6-5f62f5bd27c9 | label = 1
#   CAM min/max/mean/std: 0.0 0.9762188 0.16413721 0.17853762
#   Using threshold: 0.25340602
#   Predicted boxes (count): 7 [[0, 0, 35, 39], [98, 2, 127, 15], [37, 7, 110, 127], [95, 20, 114, 41], [14, 48, 23, 69], [124, 71, 127, 84], [0, 106, 13, 127]]
#   Best IoU for this image: 0.26912242686890575
#
# Processing PID 5c4dd6b0-4f8c-4599-8e4a-10ecacfa3494 | label = 0
#   CAM min/max/mean/std: 0.0 0.9834513 0.24551068 0.26956156
#   Using threshold: 0.38029146
#   Predicted boxes (count): 7 [[81, 0, 123, 17], [19, 7, 30, 18], [0, 8, 14, 18], [45, 8, 66, 35], [16, 42, 110, 127], [116, 49, 124, 61], [113, 72, 127, 86]]
#   Best IoU for this image: 0.0
#
# Processing PID d2360fbe-4dfb-49cc-9de1-ddd329008128 | label = 0
#   CAM min/max/mean/std: 0.0 0.9750489 0.22922009 0.26264504
#   Using threshold: 0.3605426
#   Predicted boxes (count): 7 [[0, 0, 13, 30], [45, 0, 86, 28], [111, 0, 127, 21], [105, 29, 114, 49], [0, 63, 6, 76], [28, 64, 108, 127], [4, 115, 10, 122]]
#   Best IoU for this image: 0.0
#
# Processing PID 8917b2df-a22a-4da0-935c-397926ad5a1a | label = 1
#   CAM min/max/mean/std: 0.0 0.9833652 0.22611862 0.2313084
#   Using threshold: 0.34177282
#   Predicted boxes (count): 4 [[0, 0, 25, 22], [68, 0, 75, 5], [105, 0, 124, 22], [14, 38, 113, 127]]
#   Best IoU for this image: 0.15766666666666668
#
# Processing PID eb0e6171-b47d-4996-9f53-3deb449ed835 | label = 0
#   CAM min/max/mean/std: 0.0 0.9845221 0.26154009 0.2575408
#   Using threshold: 0.39031047
#   Predicted boxes (count): 2 [[103, 0, 120, 14], [19, 46, 106, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 76115ff9-5117-45fc-831b-29bc150bf0ff | label = 0
#   CAM min/max/mean/std: 0.0 0.9937268 0.25354397 0.24872796
#   Using threshold: 0.37790796
#   Predicted boxes (count): 2 [[80, 0, 127, 16], [12, 8, 116, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 9e2ddac8-9a4c-448b-98c8-a840a548d0f7 | label = 0
#   CAM min/max/mean/std: 0.0 0.9895047 0.19574334 0.26550293
#   Using threshold: 0.3284948
#   Predicted boxes (count): 4 [[0, 0, 127, 41], [13, 26, 17, 42], [20, 63, 108, 127], [120, 85, 127, 89]]
#   Best IoU for this image: 0.0
#
# Processing PID 66f41434-28aa-48e7-aa51-261822590986 | label = 0
#   CAM min/max/mean/std: 0.0 0.9769449 0.10032542 0.17196308
#   Using threshold: 0.18630695
#   Predicted boxes (count): 5 [[28, 0, 75, 14], [115, 0, 127, 19], [100, 18, 109, 34], [117, 57, 127, 127], [19, 59, 91, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID e544e61f-adb2-4590-b2f9-c7e02ce93b15 | label = 0
#   CAM min/max/mean/std: 0.0 0.94039273 0.2683869 0.26594225
#   Using threshold: 0.401358
#   Predicted boxes (count): 8 [[43, 0, 58, 3], [80, 0, 89, 3], [59, 6, 75, 21], [104, 19, 113, 23], [0, 21, 7, 26], [25, 37, 117, 127], [13, 40, 19, 65], [0, 75, 12, 84]]
#   Best IoU for this image: 0.0
#
# Processing PID 97d33835-1ad8-4c7b-8fce-4552d9dbe2f4 | label = 1
#   CAM min/max/mean/std: 0.0 0.9720891 0.14041135 0.14006934
#   Using threshold: 0.21044602
#   Predicted boxes (count): 7 [[90, 4, 127, 28], [61, 7, 70, 24], [0, 20, 12, 29], [14, 39, 23, 58], [21, 58, 101, 127], [121, 74, 127, 96], [0, 94, 7, 125]]
#   Best IoU for this image: 0.27248265118255205
#
# Processing PID c9005a33-01c7-49c9-8d81-2a85be2c0eca | label = 0
#   CAM min/max/mean/std: 0.0 0.98916936 0.1918532 0.27698058
#   Using threshold: 0.33034348
#   Predicted boxes (count): 2 [[0, 0, 127, 18], [33, 56, 97, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 37ae5e7e-007e-4f68-be2a-40a4f5d67cbe | label = 1
#   CAM min/max/mean/std: 0.0 0.9760637 0.19513935 0.20412771
#   Using threshold: 0.2972032
#   Predicted boxes (count): 3 [[0, 0, 28, 22], [99, 6, 127, 22], [17, 65, 113, 127]]
#   Best IoU for this image: 0.1203659123736158
#
# Processing PID c210eab7-72f4-4d5a-94b2-7550ff5acf0f | label = 0
#   CAM min/max/mean/std: 0.0 0.98506296 0.17993039 0.25463927
#   Using threshold: 0.30725002
#   Predicted boxes (count): 4 [[45, 0, 127, 9], [29, 60, 99, 127], [0, 119, 24, 127], [113, 120, 127, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 27257ed5-0b0b-4840-9afd-7422ca03b3fb | label = 0
#   CAM min/max/mean/std: 0.0 0.9917826 0.1863862 0.29407483
#   Using threshold: 0.3334236
#   Predicted boxes (count): 4 [[0, 0, 127, 25], [12, 17, 20, 43], [104, 21, 115, 43], [23, 63, 103, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID b36ddceb-a4c3-4f3e-9b95-cac57da3d0b9 | label = 1
#   CAM min/max/mean/std: 0.0 0.9776373 0.21689032 0.28898388
#   Using threshold: 0.36138225
#   Predicted boxes (count): 5 [[35, 0, 72, 20], [3, 4, 27, 18], [107, 15, 127, 35], [21, 56, 95, 127], [120, 90, 127, 101]]
#   Best IoU for this image: 0.16
#
# Processing PID 292aa643-7569-4ef7-8a51-12b62440a2b0 | label = 0
#   CAM min/max/mean/std: 0.0 0.99900067 0.22320676 0.32253343
#   Using threshold: 0.38447347
#   Predicted boxes (count): 3 [[55, 0, 77, 8], [118, 0, 125, 7], [24, 59, 102, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 5862283f-aab7-4574-a235-729db2f8e377 | label = 0
#   CAM min/max/mean/std: 0.0 0.99696374 0.19561647 0.25780547
#   Using threshold: 0.32451922
#   Predicted boxes (count): 6 [[95, 0, 124, 17], [64, 6, 86, 48], [0, 19, 54, 85], [100, 29, 115, 55], [25, 64, 116, 127], [0, 90, 10, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 79dedd38-4d3e-4787-9afa-708797b1592d | label = 0
#   CAM min/max/mean/std: 0.0 0.98752016 0.29091328 0.31994298
#   Using threshold: 0.45088476
#   Predicted boxes (count): 3 [[12, 0, 115, 66], [20, 48, 102, 127], [117, 97, 127, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 2db5d817-4f4c-4773-afa0-ed3cdb3a5035 | label = 1
#   CAM min/max/mean/std: 0.0 0.98148775 0.3141687 0.24383913
#   Using threshold: 0.43608826
#   Predicted boxes (count): 2 [[99, 0, 113, 16], [13, 12, 113, 125]]
#   Best IoU for this image: 0.10838978634705576
#
# Processing PID 58b9904a-1e44-40ea-86a6-c0b9d32899f9 | label = 0
#   CAM min/max/mean/std: 0.0 0.9704416 0.14613241 0.19956931
#   Using threshold: 0.24591707
#   Predicted boxes (count): 6 [[18, 0, 94, 20], [107, 0, 125, 21], [34, 21, 46, 38], [52, 68, 108, 127], [6, 79, 22, 127], [35, 82, 46, 103]]
#   Best IoU for this image: 0.0
#
# Processing PID f64ad96d-2e62-4d8c-96d0-bc2e99b4a1a7 | label = 0
#   CAM min/max/mean/std: 0.0 0.99942225 0.25427425 0.32702017
#   Using threshold: 0.41778433
#   Predicted boxes (count): 7 [[5, 0, 14, 6], [51, 0, 67, 6], [112, 7, 125, 15], [85, 8, 98, 14], [18, 16, 22, 24], [30, 56, 96, 127], [104, 63, 111, 74]]
#   Best IoU for this image: 0.0
#
# Processing PID 8957ebd9-d891-412f-8bd7-7ecb149c4967 | label = 0
#   CAM min/max/mean/std: 0.0 0.9806247 0.27764922 0.31377423
#   Using threshold: 0.43453634
#   Predicted boxes (count): 3 [[56, 0, 82, 4], [99, 4, 120, 19], [12, 62, 115, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 4d95fe98-3899-4bf4-8d54-c0c2ca641201 | label = 0
#   CAM min/max/mean/std: 0.0 0.9985768 0.24527226 0.28534532
#   Using threshold: 0.38794494
#   Predicted boxes (count): 4 [[45, 7, 69, 31], [13, 28, 22, 67], [96, 30, 113, 61], [12, 72, 102, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID b84cd9ad-7357-47f3-910e-626667c183e5 | label = 1
#   CAM min/max/mean/std: 0.0 0.9891564 0.19614165 0.20538782
#   Using threshold: 0.29883555
#   Predicted boxes (count): 3 [[0, 0, 27, 21], [12, 57, 93, 127], [112, 72, 127, 127]]
#   Best IoU for this image: 0.11026961526810057
#
# Processing PID dac9ee71-cefa-4f46-828f-ff7dbec0b3fe | label = 0
#   CAM min/max/mean/std: 0.0 0.98076624 0.4099607 0.3217239
#   Using threshold: 0.57082266
#   Predicted boxes (count): 2 [[94, 0, 105, 9], [34, 9, 114, 125]]
#   Best IoU for this image: 0.0
#
# Processing PID bf90b850-cae0-4f24-9767-a63923beeaf3 | label = 0
#   CAM min/max/mean/std: 0.0 0.9636252 0.21505481 0.26286128
#   Using threshold: 0.34648544
#   Predicted boxes (count): 5 [[109, 0, 127, 17], [0, 7, 9, 15], [13, 23, 25, 46], [21, 48, 111, 125], [0, 93, 7, 122]]
#   Best IoU for this image: 0.0
#
# Processing PID 9924f7ec-0f0b-4574-ab99-23e4d731c519 | label = 0
#   CAM min/max/mean/std: 0.0 0.9997271 0.42065236 0.3862842
#   Using threshold: 0.61379445
#   Predicted boxes (count): 1 [[13, 30, 115, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 1436886b-785a-4767-a078-c02510681c3a | label = 0
#   CAM min/max/mean/std: 0.0 0.98743904 0.20259583 0.2963851
#   Using threshold: 0.35078838
#   Predicted boxes (count): 5 [[42, 0, 67, 12], [103, 0, 123, 16], [0, 2, 11, 10], [110, 32, 113, 50], [16, 53, 99, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 828a07b4-78cc-4ec6-8f16-863a6b308ade | label = 0
#   CAM min/max/mean/std: 0.0 0.9997642 0.2767348 0.35236788
#   Using threshold: 0.45291874
#   Predicted boxes (count): 3 [[40, 0, 49, 6], [105, 16, 114, 42], [13, 48, 102, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID d0fa7872-9743-4a81-b75e-4d8973e064b7 | label = 0
#   CAM min/max/mean/std: 0.0 0.9830507 0.13178661 0.1917331
#   Using threshold: 0.22765318
#   Predicted boxes (count): 10 [[0, 0, 15, 27], [38, 0, 80, 10], [81, 0, 120, 18], [32, 15, 41, 19], [104, 26, 108, 37], [19, 32, 22, 41], [0, 53, 10, 127], [36, 68, 93, 127], [98, 92, 112, 103], [16, 100, 24, 106]]
#   Best IoU for this image: 0.0
#
# Processing PID d7d7e6cd-012b-46d7-8596-dc90e99bfd5d | label = 0
#   CAM min/max/mean/std: 0.0 0.994838 0.24537048 0.30720356
#   Using threshold: 0.39897227
#   Predicted boxes (count): 4 [[0, 0, 102, 8], [109, 0, 127, 25], [105, 37, 113, 59], [19, 57, 98, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 99096098-a4bd-476b-949d-40cf2fcfc2c9 | label = 0
#   CAM min/max/mean/std: 0.0 0.99971306 0.23889676 0.33799312
#   Using threshold: 0.4078933
#   Predicted boxes (count): 4 [[53, 0, 68, 10], [13, 33, 15, 54], [109, 32, 114, 56], [19, 62, 106, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID f9c4f02b-52b5-4f36-96d7-b706d678d9b9 | label = 1
#   CAM min/max/mean/std: 0.0 0.9675406 0.21604033 0.24106775
#   Using threshold: 0.3365742
#   Predicted boxes (count): 2 [[4, 0, 23, 15], [12, 68, 114, 127]]
#   Best IoU for this image: 0.030517879161528975
#
# Processing PID 4c38a298-94e2-460f-b40e-f8ec669afebb | label = 0
#   CAM min/max/mean/std: 0.0 0.99802125 0.16247696 0.27906832
#   Using threshold: 0.30201113
#   Predicted boxes (count): 7 [[47, 0, 67, 21], [104, 0, 125, 15], [0, 11, 7, 17], [12, 24, 19, 45], [84, 25, 90, 33], [20, 49, 111, 127], [0, 97, 15, 119]]
#   Best IoU for this image: 0.0
#
# Processing PID 7cd222a5-4714-418f-80ac-20f42c738363 | label = 0
#   CAM min/max/mean/std: 0.0 0.9997938 0.28414682 0.36574498
#   Using threshold: 0.46701932
#   Predicted boxes (count): 4 [[59, 8, 82, 19], [108, 14, 114, 22], [12, 17, 33, 42], [33, 42, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID fa231b7a-839b-43b2-8e52-19ddef1327da | label = 0
#   CAM min/max/mean/std: 0.0 0.9638961 0.23910853 0.3036855
#   Using threshold: 0.39095128
#   Predicted boxes (count): 3 [[110, 0, 127, 14], [13, 16, 23, 54], [12, 58, 115, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID cb3816db-93c9-4d0a-a163-eb40363c45fe | label = 1
#   CAM min/max/mean/std: 0.0 0.99230105 0.14118746 0.13462952
#   Using threshold: 0.20850222
#   Predicted boxes (count): 5 [[0, 7, 78, 43], [87, 45, 108, 98], [36, 46, 78, 102], [15, 52, 29, 78], [3, 81, 13, 97]]
#   Best IoU for this image: 0.23297380585516178
#
# Processing PID 3db7e979-5f97-4985-bf0c-cdea7951e246 | label = 1
#   CAM min/max/mean/std: 0.0 0.9887628 0.17378303 0.1652899
#   Using threshold: 0.25642797
#   Predicted boxes (count): 10 [[48, 0, 83, 8], [90, 0, 127, 28], [25, 17, 44, 26], [0, 21, 12, 34], [121, 46, 127, 59], [37, 52, 96, 125], [0, 60, 15, 127], [121, 74, 127, 82], [16, 84, 27, 108], [115, 119, 127, 127]]
#   Best IoU for this image: 0.1662914120295915
#
# Processing PID d01fc6b0-cdc1-428a-9d1a-82ea647aefc7 | label = 0
#   CAM min/max/mean/std: 0.0 0.99918073 0.30790946 0.35765013
#   Using threshold: 0.4867345
#   Predicted boxes (count): 4 [[58, 9, 68, 36], [105, 29, 114, 60], [12, 43, 115, 127], [85, 62, 90, 67]]
#   Best IoU for this image: 0.0
#
# Processing PID e6902ba2-a732-4c34-b586-ad631c701ee3 | label = 0
#   CAM min/max/mean/std: 0.0 0.9992713 0.41094464 0.39651752
#   Using threshold: 0.6092034
#   Predicted boxes (count): 1 [[12, 35, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID e54886f4-c110-4606-a543-f628b8cff558 | label = 0
#   CAM min/max/mean/std: 0.0 0.98674667 0.18753897 0.2745329
#   Using threshold: 0.32480544
#   Predicted boxes (count): 7 [[0, 0, 7, 6], [47, 0, 68, 12], [94, 11, 115, 39], [12, 15, 27, 39], [102, 62, 116, 114], [4, 67, 22, 115], [28, 73, 91, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID ad182aff-7085-408e-bac3-51a7c705a711 | label = 0
#   CAM min/max/mean/std: 0.0 0.996944 0.23462479 0.28478214
#   Using threshold: 0.37701586
#   Predicted boxes (count): 6 [[0, 0, 88, 21], [93, 7, 127, 31], [12, 21, 24, 47], [91, 26, 112, 67], [12, 68, 91, 127], [116, 78, 127, 121]]
#   Best IoU for this image: 0.0
#
# Processing PID 853eb3dc-762c-4b84-901e-3399addf1fe6 | label = 1
#   CAM min/max/mean/std: 0.0 0.9791544 0.17126033 0.2094558
#   Using threshold: 0.27598822
#   Predicted boxes (count): 6 [[52, 0, 67, 5], [77, 0, 90, 3], [106, 0, 124, 20], [15, 16, 34, 28], [24, 64, 103, 127], [0, 121, 11, 127]]
#   Best IoU for this image: 0.05246913580246913
#
# Processing PID ea05ad67-8667-4f4c-a4a3-d37c3d9ba80e | label = 0
#   CAM min/max/mean/std: 0.0 0.9990613 0.3749792 0.32582855
#   Using threshold: 0.5378935
#   Predicted boxes (count): 2 [[13, 47, 114, 127], [115, 52, 121, 57]]
#   Best IoU for this image: 0.0
#
# Processing PID 523ad7b7-2430-4621-a90d-02d0e33f99a2 | label = 1
#   CAM min/max/mean/std: 0.0 0.9833821 0.29031742 0.29231948
#   Using threshold: 0.43647715
#   Predicted boxes (count): 5 [[29, 0, 53, 6], [0, 9, 19, 34], [84, 11, 118, 22], [120, 43, 127, 81], [19, 58, 97, 127]]
#   Best IoU for this image: 0.19848771266540643
#
# Processing PID ecbe84f7-1283-4131-bea3-d8b380179c47 | label = 0
#   CAM min/max/mean/std: 0.0 0.9893947 0.20195846 0.30520117
#   Using threshold: 0.35455906
#   Predicted boxes (count): 6 [[0, 0, 127, 22], [4, 17, 10, 22], [13, 31, 22, 50], [108, 35, 115, 58], [0, 63, 7, 72], [28, 71, 104, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 1fd8e4db-3283-44a1-a591-6e3e49f248ab | label = 1
#   CAM min/max/mean/std: 0.0 0.97128385 0.20893994 0.22634296
#   Using threshold: 0.32211143
#   Predicted boxes (count): 2 [[0, 0, 15, 21], [14, 62, 114, 127]]
#   Best IoU for this image: 0.11026102610261027
#
# Processing PID ff0fcf72-7b10-4c5c-bb43-f81368872b9b | label = 0
#   CAM min/max/mean/std: 0.0 0.979241 0.18248127 0.24960053
#   Using threshold: 0.30728155
#   Predicted boxes (count): 6 [[44, 0, 127, 19], [3, 13, 8, 18], [12, 28, 26, 65], [106, 29, 115, 55], [19, 54, 106, 127], [105, 98, 110, 106]]
#   Best IoU for this image: 0.0
#
# Processing PID c9aafb1b-ee49-4eb1-817b-675100ca2c4d | label = 0
#   CAM min/max/mean/std: 0.0 0.96775264 0.13416131 0.1540671
#   Using threshold: 0.21119486
#   Predicted boxes (count): 5 [[0, 0, 25, 16], [67, 0, 78, 4], [96, 0, 104, 8], [103, 0, 127, 25], [13, 60, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 4b004c64-d809-4309-9840-bdf38aaed74a | label = 0
#   CAM min/max/mean/std: 0.0 0.999339 0.36625394 0.31479666
#   Using threshold: 0.52365226
#   Predicted boxes (count): 2 [[12, 0, 115, 82], [21, 51, 112, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID f9d7c652-d12b-4351-b3f6-da8e2473f5e3 | label = 0
#   CAM min/max/mean/std: 0.0 0.99858844 0.22402373 0.2894908
#   Using threshold: 0.3687691
#   Predicted boxes (count): 4 [[2, 0, 34, 12], [110, 25, 113, 53], [19, 52, 107, 127], [122, 76, 127, 96]]
#   Best IoU for this image: 0.0
#
# Processing PID a1dc7fe9-1e55-4956-9f04-f99f624faefb | label = 0
#   CAM min/max/mean/std: 0.0 0.9947229 0.20130447 0.26023737
#   Using threshold: 0.33142316
#   Predicted boxes (count): 4 [[0, 0, 127, 14], [109, 29, 114, 50], [83, 46, 95, 58], [14, 61, 110, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 7a713bb9-19f5-42ba-81cf-b4905a00ebb1 | label = 0
#   CAM min/max/mean/std: 0.0 0.971619 0.13434204 0.17448822
#   Using threshold: 0.22158615
#   Predicted boxes (count): 7 [[46, 0, 124, 37], [4, 10, 30, 27], [21, 29, 34, 41], [0, 67, 10, 89], [36, 66, 106, 127], [124, 69, 127, 82], [115, 113, 127, 125]]
#   Best IoU for this image: 0.0
#
# Processing PID 936f2425-bc13-49ce-a4a1-979fd314ab48 | label = 1
#   CAM min/max/mean/std: 0.0 0.97041374 0.25967345 0.2649491
#   Using threshold: 0.39214802
#   Predicted boxes (count): 3 [[24, 0, 34, 7], [102, 0, 116, 12], [17, 52, 114, 127]]
#   Best IoU for this image: 0.25627615062761505
#
# Processing PID f5dc76a7-237a-419c-a28a-c3fc7ff43b65 | label = 1
#   CAM min/max/mean/std: 0.0 0.9747624 0.23401949 0.2008746
#   Using threshold: 0.3344568
#   Predicted boxes (count): 4 [[98, 0, 114, 15], [41, 9, 68, 44], [22, 22, 114, 127], [14, 34, 21, 55]]
#   Best IoU for this image: 0.10621605310802655
#
# Processing PID c5b5c787-ec1f-4a20-ae1d-e58e93da0474 | label = 0
#   CAM min/max/mean/std: 0.0 0.9758724 0.25770134 0.27133182
#   Using threshold: 0.39336723
#   Predicted boxes (count): 3 [[0, 0, 15, 18], [111, 34, 127, 56], [12, 64, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID e2ad3d7c-e284-46df-ad80-b6d04dfda188 | label = 0
#   CAM min/max/mean/std: 0.0 0.9757009 0.21332671 0.27363008
#   Using threshold: 0.35014176
#   Predicted boxes (count): 5 [[3, 0, 28, 22], [50, 0, 63, 6], [86, 0, 127, 14], [65, 7, 84, 19], [15, 56, 116, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID ad410976-c87b-444f-abd7-36b1292d680b | label = 1
#   CAM min/max/mean/std: 0.0 0.99961746 0.2905431 0.34854025
#   Using threshold: 0.46481323
#   Predicted boxes (count): 4 [[60, 8, 66, 23], [13, 37, 21, 67], [103, 41, 113, 68], [16, 54, 103, 127]]
#   Best IoU for this image: 0.07985257985257985
#
# Processing PID 5673f2ae-da70-4301-b2ba-dfb6e9f84085 | label = 0
#   CAM min/max/mean/std: 0.0 0.98174626 0.18547103 0.16220044
#   Using threshold: 0.26657125
#   Predicted boxes (count): 7 [[12, 0, 24, 9], [55, 0, 81, 6], [89, 3, 105, 13], [42, 8, 53, 18], [13, 35, 38, 93], [54, 41, 98, 125], [107, 51, 127, 71]]
#   Best IoU for this image: 0.0
#
# Processing PID f5cb4b26-5821-4b91-90a0-629f4f0cbd2f | label = 1
#   CAM min/max/mean/std: 0.0 0.99975675 0.44405144 0.38140163
#   Using threshold: 0.6347523
#   Predicted boxes (count): 2 [[3, 0, 11, 7], [34, 9, 114, 124]]
#   Best IoU for this image: 0.07492550021285653
#
# Processing PID 59924efe-8577-42a8-87ca-30587eee3f1b | label = 0
#   CAM min/max/mean/std: 0.0 0.9780471 0.23645815 0.26352513
#   Using threshold: 0.36822072
#   Predicted boxes (count): 4 [[27, 0, 48, 8], [105, 0, 127, 43], [9, 12, 20, 21], [37, 63, 116, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID cbf79874-5afe-4530-baf8-0e70bbf5f135 | label = 0
#   CAM min/max/mean/std: 0.0 0.9988672 0.1817863 0.25605687
#   Using threshold: 0.30981475
#   Predicted boxes (count): 10 [[47, 0, 72, 30], [78, 0, 87, 5], [99, 0, 123, 16], [0, 9, 13, 19], [96, 22, 115, 47], [12, 28, 31, 52], [0, 65, 8, 81], [28, 72, 91, 127], [106, 86, 124, 127], [8, 88, 24, 117]]
#   Best IoU for this image: 0.0
#
# Processing PID fc8878b8-aa5b-4ae1-9a32-de3abda9256e | label = 0
#   CAM min/max/mean/std: 0.0 0.98133487 0.22923663 0.2727089
#   Using threshold: 0.36559108
#   Predicted boxes (count): 2 [[110, 0, 127, 18], [12, 50, 118, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID ae76e24d-14d2-4937-aaae-3a2b0aa0e2c6 | label = 1
#   CAM min/max/mean/std: 0.0 0.99939823 0.2443457 0.3183307
#   Using threshold: 0.40351105
#   Predicted boxes (count): 5 [[40, 0, 57, 6], [105, 5, 116, 18], [57, 20, 65, 29], [17, 45, 22, 61], [20, 64, 112, 127]]
#   Best IoU for this image: 0.07426075268817205
#
# Processing PID 8ab8dfdb-1afe-4e18-8a75-e6ac7ebc3fae | label = 0
#   CAM min/max/mean/std: 0.0 0.99958634 0.25319904 0.34028617
#   Using threshold: 0.4233421
#   Predicted boxes (count): 3 [[32, 0, 73, 8], [118, 7, 127, 18], [12, 67, 116, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 908269da-adb0-4b50-a608-48bc7a1e42d6 | label = 0
#   CAM min/max/mean/std: 0.0 0.9761974 0.23843376 0.30069876
#   Using threshold: 0.38878316
#   Predicted boxes (count): 3 [[0, 0, 127, 14], [24, 53, 95, 127], [118, 76, 127, 118]]
#   Best IoU for this image: 0.0
#
# Processing PID 26727770-8a9a-457c-9c98-ce0e6bc95962 | label = 0
#   CAM min/max/mean/std: 0.0 0.97411424 0.21229371 0.24466594
#   Using threshold: 0.33462667
#   Predicted boxes (count): 7 [[0, 0, 16, 11], [34, 0, 85, 22], [105, 0, 127, 15], [13, 16, 25, 35], [99, 17, 114, 47], [24, 44, 102, 127], [4, 85, 6, 98]]
#   Best IoU for this image: 0.0
#
# Processing PID 44476603-8ea4-4a46-83a5-a4bc90649282 | label = 0
#   CAM min/max/mean/std: 0.0 0.99787945 0.20121993 0.29464635
#   Using threshold: 0.3485431
#   Predicted boxes (count): 7 [[43, 0, 82, 11], [110, 0, 127, 11], [0, 11, 13, 22], [88, 11, 101, 18], [109, 25, 115, 45], [12, 30, 22, 51], [27, 66, 107, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID e57849e2-d2b9-4ab6-a3e3-0263a4a78b33 | label = 0
#   CAM min/max/mean/std: 0.0 0.9989033 0.37679875 0.29712415
#   Using threshold: 0.5253608
#   Predicted boxes (count): 5 [[43, 0, 82, 8], [0, 15, 11, 23], [23, 15, 34, 25], [109, 24, 121, 34], [24, 54, 113, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 0cb05380-5ae8-46de-8585-41b5323d7c65 | label = 1
#   CAM min/max/mean/std: 0.0 0.97270006 0.2725932 0.21247111
#   Using threshold: 0.37882876
#   Predicted boxes (count): 5 [[96, 0, 127, 37], [24, 8, 34, 14], [0, 43, 7, 66], [120, 57, 127, 64], [18, 58, 111, 127]]
#   Best IoU for this image: 0.17378048780487804
#
# Processing PID 4b3eb3a0-bb4a-4746-b4a4-62eb002849f7 | label = 0
#   CAM min/max/mean/std: 0.0 0.9818536 0.14427114 0.19747743
#   Using threshold: 0.24300985
#   Predicted boxes (count): 8 [[50, 0, 69, 8], [102, 6, 123, 25], [3, 12, 46, 25], [82, 16, 93, 22], [122, 36, 127, 52], [0, 53, 9, 73], [37, 66, 91, 127], [17, 84, 31, 98]]
#   Best IoU for this image: 0.0
#
# Processing PID 2a689cee-3fa4-405a-98de-da24278e7d33 | label = 0
#   CAM min/max/mean/std: 0.0 0.98745173 0.20405893 0.3024285
#   Using threshold: 0.3552732
#   Predicted boxes (count): 4 [[30, 0, 127, 21], [13, 32, 18, 59], [108, 34, 114, 64], [19, 69, 106, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 9589ff7f-3153-4031-aef8-25d8916ab392 | label = 0
#   CAM min/max/mean/std: 0.0 0.99928206 0.35614312 0.3748764
#   Using threshold: 0.5435813
#   Predicted boxes (count): 3 [[58, 7, 81, 20], [12, 12, 114, 127], [101, 17, 114, 65]]
#   Best IoU for this image: 0.0
#
# Processing PID fcd159f4-21d3-4169-a94b-95a2b5ccddcb | label = 1
#   CAM min/max/mean/std: 0.0 0.95927 0.1727187 0.1756159
#   Using threshold: 0.26052666
#   Predicted boxes (count): 6 [[101, 0, 127, 20], [0, 17, 18, 26], [100, 28, 114, 87], [29, 62, 111, 127], [3, 65, 12, 73], [0, 91, 12, 127]]
#   Best IoU for this image: 0.2730627306273063
#
# Processing PID e088ad69-eac7-4438-9230-1c7320dfaad4 | label = 0
#   CAM min/max/mean/std: 0.0 0.9979731 0.34247983 0.34125453
#   Using threshold: 0.51310706
#   Predicted boxes (count): 6 [[36, 0, 93, 13], [104, 3, 127, 19], [0, 5, 11, 22], [13, 32, 17, 50], [106, 37, 110, 52], [13, 46, 111, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID f8fef94a-8314-462a-a3de-a45fd2265efe | label = 0
#   CAM min/max/mean/std: 0.0 0.9990317 0.24809244 0.34206498
#   Using threshold: 0.41912493
#   Predicted boxes (count): 6 [[111, 0, 127, 11], [60, 6, 71, 18], [0, 8, 11, 16], [107, 21, 114, 37], [13, 24, 21, 60], [12, 55, 107, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID ff955beb-6f41-4292-adf7-f224054c882f | label = 0
#   CAM min/max/mean/std: 0.0 0.9992038 0.25171757 0.3380337
#   Using threshold: 0.4207344
#   Predicted boxes (count): 5 [[40, 0, 53, 2], [109, 0, 120, 9], [54, 7, 61, 14], [13, 32, 17, 55], [17, 56, 103, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID fb0579b0-ea15-46a8-9d2f-f769bf7dc32d | label = 0
#   CAM min/max/mean/std: 0.0 0.9757727 0.27934968 0.21694688
#   Using threshold: 0.38782313
#   Predicted boxes (count): 2 [[100, 0, 114, 13], [13, 9, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 3f750eed-bfad-4c3f-b268-8c9f4270cf05 | label = 1
#   CAM min/max/mean/std: 0.0 0.9719602 0.054856703 0.1137971
#   Using threshold: 0.11175525
#   Predicted boxes (count): 4 [[0, 0, 48, 19], [91, 0, 127, 21], [41, 83, 65, 127], [10, 113, 24, 119]]
#   Best IoU for this image: 0.0
#
# Processing PID 05d3817a-5535-4e77-8dda-d4412e496c81 | label = 1
#   CAM min/max/mean/std: 0.0 0.9714016 0.18272054 0.15048909
#   Using threshold: 0.2579651
#   Predicted boxes (count): 3 [[106, 0, 127, 15], [16, 9, 102, 127], [120, 97, 127, 124]]
#   Best IoU for this image: 0.290736984448952
#
# Processing PID 86e054aa-1863-46a0-9f9d-1a8ed005010d | label = 0
#   CAM min/max/mean/std: 0.0 0.99922305 0.20159948 0.30607486
#   Using threshold: 0.3546369
#   Predicted boxes (count): 6 [[49, 0, 67, 12], [105, 8, 122, 21], [12, 27, 15, 51], [105, 26, 115, 49], [30, 60, 95, 127], [11, 87, 21, 98]]
#   Best IoU for this image: 0.0
#
# Processing PID 9383d552-f959-47d0-8f08-27038b1e6605 | label = 0
#   CAM min/max/mean/std: 0.0 0.999488 0.23831399 0.34267563
#   Using threshold: 0.40965182
#   Predicted boxes (count): 4 [[39, 0, 127, 15], [12, 15, 25, 48], [108, 21, 114, 56], [20, 63, 104, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 16939adb-3468-4e45-9b87-0ec9a8b0f2ea | label = 1
#   CAM min/max/mean/std: 0.0 0.9836209 0.2173946 0.19421525
#   Using threshold: 0.31450224
#   Predicted boxes (count): 4 [[0, 0, 12, 20], [37, 0, 80, 7], [99, 3, 127, 19], [18, 28, 110, 125]]
#   Best IoU for this image: 0.1867456660083388
#
# Processing PID befa7299-aa28-4487-b497-262ad6cd8f1c | label = 1
#   CAM min/max/mean/std: 0.0 0.9791957 0.12843908 0.15883377
#   Using threshold: 0.20785597
#   Predicted boxes (count): 7 [[44, 0, 63, 6], [77, 0, 88, 6], [107, 0, 127, 44], [5, 9, 17, 17], [65, 8, 70, 13], [0, 29, 7, 40], [24, 69, 105, 127]]
#   Best IoU for this image: 0.13778904022806462
#
# Processing PID 99fea771-32df-4faa-a102-70ef7c659898 | label = 0
#   CAM min/max/mean/std: 0.0 0.97685647 0.30446824 0.26380488
#   Using threshold: 0.43637067
#   Predicted boxes (count): 3 [[112, 0, 127, 13], [0, 7, 7, 17], [13, 35, 110, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID c1696635-dfc2-4215-ac85-46825953fc82 | label = 0
#   CAM min/max/mean/std: 0.0 0.96681917 0.18365347 0.25132626
#   Using threshold: 0.3093166
#   Predicted boxes (count): 4 [[52, 0, 67, 14], [107, 0, 127, 18], [3, 4, 14, 14], [28, 47, 102, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID b215a2cf-ddf6-4032-99a0-1c2b10ef2f9e | label = 0
#   CAM min/max/mean/std: 0.0 0.99983823 0.4588325 0.38896814
#   Using threshold: 0.65331656
#   Predicted boxes (count): 3 [[108, 5, 115, 13], [13, 27, 20, 51], [13, 37, 114, 125]]
#   Best IoU for this image: 0.0
#
# Processing PID a3a3b1ab-17d0-44e2-9e7a-48f78e3bcb1c | label = 0
#   CAM min/max/mean/std: 0.0 0.9644151 0.2247989 0.22677012
#   Using threshold: 0.33818397
#   Predicted boxes (count): 4 [[112, 0, 127, 13], [44, 9, 63, 19], [13, 11, 101, 127], [87, 12, 114, 91]]
#   Best IoU for this image: 0.0
#
# Processing PID 31eb47ce-891a-44f3-9031-96d8952b487c | label = 0
#   CAM min/max/mean/std: 0.0 0.9990057 0.2542486 0.32581446
#   Using threshold: 0.4171558
#   Predicted boxes (count): 5 [[49, 0, 62, 6], [88, 3, 123, 25], [6, 6, 15, 13], [36, 13, 43, 21], [21, 62, 103, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID ee4e07ab-4605-47a5-895b-343a6e2308ce | label = 0
#   CAM min/max/mean/std: 0.0 0.96589416 0.20606086 0.28993893
#   Using threshold: 0.35103032
#   Predicted boxes (count): 3 [[104, 5, 123, 22], [3, 8, 9, 13], [16, 66, 103, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 6025fe0f-24d5-4dc6-857d-a95ebb9af98a | label = 0
#   CAM min/max/mean/std: 0.0 0.99948126 0.2886855 0.33387712
#   Using threshold: 0.45562404
#   Predicted boxes (count): 3 [[53, 7, 76, 19], [21, 17, 115, 127], [12, 26, 25, 94]]
#   Best IoU for this image: 0.0
#
# Processing PID f135d126-5a13-44ed-bb30-3334cbc2b7f2 | label = 0
#   CAM min/max/mean/std: 0.0 0.9996246 0.3499334 0.3099647
#   Using threshold: 0.5049157
#   Predicted boxes (count): 2 [[0, 2, 9, 7], [13, 58, 102, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID b4fe242c-892f-4839-9aa6-d6b140649635 | label = 0
#   CAM min/max/mean/std: 0.0 0.9624057 0.1424168 0.15105015
#   Using threshold: 0.21794188
#   Predicted boxes (count): 7 [[31, 0, 63, 18], [110, 0, 127, 15], [80, 6, 90, 18], [35, 38, 89, 127], [117, 60, 123, 87], [116, 117, 127, 127], [98, 121, 104, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID f1bdcb61-a159-40d8-83a8-d08e47202289 | label = 0
#   CAM min/max/mean/std: 0.0 0.96902907 0.14210936 0.17570096
#   Using threshold: 0.22995985
#   Predicted boxes (count): 5 [[0, 0, 127, 35], [12, 27, 28, 67], [100, 28, 115, 73], [21, 57, 102, 127], [116, 103, 127, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID c52d38e9-b26f-4422-8880-6a4db0ba5bb9 | label = 0
#   CAM min/max/mean/std: 0.0 0.9456608 0.1660431 0.16035426
#   Using threshold: 0.24622023
#   Predicted boxes (count): 4 [[6, 0, 39, 65], [60, 0, 127, 21], [33, 57, 94, 127], [112, 65, 127, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 48a74e9c-c0bb-4eeb-85f7-6ca980152001 | label = 0
#   CAM min/max/mean/std: 0.0 0.96901983 0.12039718 0.15802704
#   Using threshold: 0.1994107
#   Predicted boxes (count): 2 [[85, 0, 127, 31], [12, 63, 118, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 296c307e-cf85-4ef4-95eb-7a05d4576dfa | label = 1
#   CAM min/max/mean/std: 0.0 0.9312849 0.30738157 0.29458845
#   Using threshold: 0.4546758
#   Predicted boxes (count): 2 [[13, 0, 121, 127], [19, 9, 48, 38]]
#   Best IoU for this image: 0.025802752293577983
#
# Processing PID 77c19750-2f89-4c77-85f9-6e9494e5e842 | label = 0
#   CAM min/max/mean/std: 0.0 0.9760659 0.2307654 0.25390458
#   Using threshold: 0.3577177
#   Predicted boxes (count): 5 [[109, 4, 125, 18], [60, 8, 75, 16], [17, 18, 29, 44], [110, 29, 114, 59], [24, 35, 105, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 75ecaed3-c912-4459-9095-ec6674f524e3 | label = 0
#   CAM min/max/mean/std: 0.0 0.97534347 0.16196066 0.19623092
#   Using threshold: 0.2600761
#   Predicted boxes (count): 7 [[45, 12, 127, 58], [8, 16, 31, 29], [8, 36, 13, 46], [24, 44, 37, 67], [101, 50, 110, 71], [26, 63, 127, 109], [8, 99, 16, 107]]
#   Best IoU for this image: 0.0
#
# Processing PID 727338a7-43b6-40cb-9b2a-d03d10f46325 | label = 0
#   CAM min/max/mean/std: 0.0 0.9994821 0.25299817 0.3397609
#   Using threshold: 0.42287862
#   Predicted boxes (count): 5 [[98, 7, 118, 21], [3, 13, 9, 18], [13, 33, 15, 56], [109, 34, 114, 59], [13, 63, 105, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID f661fe70-2fc1-4564-9f53-45504c0b0688 | label = 1
#   CAM min/max/mean/std: 0.0 0.97468126 0.17995396 0.17883863
#   Using threshold: 0.26937327
#   Predicted boxes (count): 5 [[0, 0, 29, 23], [48, 0, 59, 6], [88, 0, 121, 21], [16, 28, 84, 127], [119, 42, 127, 73]]
#   Best IoU for this image: 0.18869565217391304
#
# Processing PID 25af79cb-2656-4565-ae88-ff98eccced9a | label = 0
#   CAM min/max/mean/std: 0.0 0.9671814 0.24230306 0.32941282
#   Using threshold: 0.40700948
#   Predicted boxes (count): 4 [[51, 0, 65, 16], [0, 3, 10, 22], [110, 3, 127, 18], [17, 56, 110, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 46b05a16-18c0-4525-a332-1c2c23abc98e | label = 0
#   CAM min/max/mean/std: 0.0 0.99906224 0.30680013 0.32561502
#   Using threshold: 0.46960765
#   Predicted boxes (count): 4 [[33, 0, 46, 6], [111, 0, 127, 12], [3, 3, 18, 20], [13, 52, 102, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 38e99364-5995-4b7c-ad87-f8b558a0b5a4 | label = 0
#   CAM min/max/mean/std: 0.0 0.99953985 0.33528543 0.37487835
#   Using threshold: 0.5227246
#   Predicted boxes (count): 4 [[53, 0, 67, 6], [116, 5, 125, 13], [0, 12, 12, 22], [13, 57, 115, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 1c98cf85-1e50-4def-a8e7-6749808339ff | label = 1
#   CAM min/max/mean/std: 0.0 0.9793813 0.24598354 0.18336867
#   Using threshold: 0.33766788
#   Predicted boxes (count): 10 [[44, 0, 69, 7], [102, 0, 117, 6], [77, 3, 92, 13], [4, 4, 13, 14], [111, 15, 127, 51], [0, 31, 5, 37], [26, 56, 106, 127], [0, 58, 6, 65], [3, 82, 7, 95], [6, 104, 10, 114]]
#   Best IoU for this image: 0.09722222222222222
#
# Processing PID 4cbab323-9aa3-49cd-97c7-5fbae3e53a66 | label = 0
#   CAM min/max/mean/std: 0.0 0.9992559 0.45582715 0.39265567
#   Using threshold: 0.652155
#   Predicted boxes (count): 1 [[14, 25, 114, 125]]
#   Best IoU for this image: 0.0
#
# Processing PID 21dc80a4-e6b7-4cfc-9463-3fc2f660833f | label = 1
#   CAM min/max/mean/std: 0.0 0.9796273 0.22325656 0.24308519
#   Using threshold: 0.34479916
#   Predicted boxes (count): 6 [[55, 0, 73, 6], [94, 2, 122, 20], [2, 8, 38, 22], [21, 60, 95, 127], [109, 61, 127, 124], [0, 118, 6, 127]]
#   Best IoU for this image: 0.2631578947368421
#
# Processing PID 80a5e433-c26e-4701-a88b-271467ed3163 | label = 0
#   CAM min/max/mean/std: 0.0 0.98100865 0.29323095 0.25105557
#   Using threshold: 0.41875875
#   Predicted boxes (count): 3 [[20, 13, 116, 127], [0, 14, 10, 25], [14, 34, 19, 66]]
#   Best IoU for this image: 0.0
#
# Processing PID b7069aa5-9e33-4918-aba2-f76b0abef6a4 | label = 1
#   CAM min/max/mean/std: 0.0 0.9995484 0.32936648 0.3576321
#   Using threshold: 0.5081825
#   Predicted boxes (count): 4 [[109, 9, 118, 18], [0, 13, 6, 18], [13, 29, 17, 43], [17, 42, 109, 127]]
#   Best IoU for this image: 0.10357583230579531
#
# Processing PID bf4ba376-dfef-4d19-bbd6-923325b58eb1 | label = 1
#   CAM min/max/mean/std: 0.0 0.9977681 0.17381176 0.21727021
#   Using threshold: 0.28244686
#   Predicted boxes (count): 4 [[43, 0, 127, 16], [3, 6, 11, 13], [17, 45, 25, 75], [20, 68, 111, 127]]
#   Best IoU for this image: 0.14130434782608695
#
# Processing PID 626f28a9-ec6f-4e44-b393-503ab394358d | label = 0
#   CAM min/max/mean/std: 0.0 0.97436595 0.17787583 0.19484822
#   Using threshold: 0.27529994
#   Predicted boxes (count): 8 [[0, 0, 37, 28], [56, 0, 77, 6], [100, 5, 110, 13], [115, 5, 127, 14], [0, 41, 7, 57], [21, 47, 26, 73], [110, 48, 113, 59], [30, 62, 110, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 85a38f61-752c-4a5a-9a9a-eabc2889bc06 | label = 0
#   CAM min/max/mean/std: 0.0 0.9682091 0.19120558 0.18904668
#   Using threshold: 0.28572893
#   Predicted boxes (count): 6 [[36, 0, 82, 9], [106, 2, 127, 25], [0, 4, 12, 23], [13, 32, 21, 48], [101, 33, 108, 48], [17, 57, 100, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 53bae9fc-3bb2-4684-b986-84bf7aa2e5a2 | label = 0
#   CAM min/max/mean/std: 0.0 0.99915206 0.24036528 0.33632
#   Using threshold: 0.4085253
#   Predicted boxes (count): 4 [[51, 0, 61, 6], [102, 5, 116, 21], [2, 13, 12, 22], [12, 70, 107, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID ce7de6c5-a66f-4c77-913a-7d29fe5ea882 | label = 0
#   CAM min/max/mean/std: 0.0 0.9992501 0.27982578 0.37124434
#   Using threshold: 0.46544796
#   Predicted boxes (count): 3 [[116, 3, 127, 14], [13, 33, 18, 58], [17, 56, 112, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID b95ddea5-0c01-4b30-817a-e3daa23c723a | label = 1
#   CAM min/max/mean/std: 0.0 0.9997893 0.1794429 0.2854398
#   Using threshold: 0.3221628
#   Predicted boxes (count): 5 [[39, 0, 64, 27], [5, 7, 15, 10], [101, 25, 114, 51], [16, 56, 99, 127], [0, 92, 7, 103]]
#   Best IoU for this image: 0.1342281879194631
#
# Processing PID e1161d19-41cc-4180-a7f1-32cf609851e6 | label = 0
#   CAM min/max/mean/std: 0.0 0.9754556 0.22343735 0.24679613
#   Using threshold: 0.34683543
#   Predicted boxes (count): 7 [[0, 0, 12, 9], [25, 0, 41, 9], [47, 0, 112, 18], [14, 17, 25, 37], [24, 34, 90, 127], [0, 75, 11, 114], [116, 115, 119, 125]]
#   Best IoU for this image: 0.0
#
# Processing PID d6b17789-d8cd-4487-99c8-baecc7e18747 | label = 0
#   CAM min/max/mean/std: 0.0 0.9995789 0.268234 0.33000514
#   Using threshold: 0.4332366
#   Predicted boxes (count): 4 [[52, 0, 88, 7], [108, 7, 121, 22], [15, 35, 26, 52], [23, 63, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 9280ca7a-4bc1-478a-90a8-09d87079f944 | label = 0
#   CAM min/max/mean/std: 0.0 0.94916826 0.2086299 0.21268667
#   Using threshold: 0.31497324
#   Predicted boxes (count): 5 [[40, 0, 83, 15], [13, 0, 115, 114], [4, 2, 30, 16], [114, 100, 127, 113], [0, 112, 22, 124]]
#   Best IoU for this image: 0.0
#
# Processing PID e9879f2c-d754-4778-917e-a33dc5df0f0e | label = 0
#   CAM min/max/mean/std: 0.0 0.9997446 0.2603059 0.35159886
#   Using threshold: 0.43610534
#   Predicted boxes (count): 4 [[109, 3, 125, 15], [13, 25, 17, 38], [106, 28, 114, 67], [12, 61, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID d58bd53a-c69c-443e-851d-479a78d1c9b2 | label = 0
#   CAM min/max/mean/std: 0.0 0.954243 0.23938675 0.29900512
#   Using threshold: 0.3888893
#   Predicted boxes (count): 4 [[110, 2, 127, 18], [50, 8, 66, 26], [105, 29, 114, 55], [13, 30, 106, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID c8e36af3-6b75-49ac-b144-975daf5aaa38 | label = 0
#   CAM min/max/mean/std: 0.0 0.9826745 0.25367796 0.29056886
#   Using threshold: 0.39896238
#   Predicted boxes (count): 3 [[43, 0, 52, 5], [2, 3, 25, 31], [12, 58, 117, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID a30e9f7b-4de5-4e40-afc3-cf23361a14e2 | label = 1
#   CAM min/max/mean/std: 0.0 0.9980483 0.18803631 0.29005173
#   Using threshold: 0.33306217
#   Predicted boxes (count): 7 [[0, 0, 16, 19], [53, 0, 71, 9], [116, 2, 127, 12], [87, 9, 104, 19], [33, 15, 44, 23], [28, 57, 105, 127], [0, 60, 6, 72]]
#   Best IoU for this image: 0.006453694740238786
#
# Processing PID 6c4c47b3-ef67-4403-bdbc-9193f5435996 | label = 0
#   CAM min/max/mean/std: 0.0 0.9797988 0.26843306 0.21138829
#   Using threshold: 0.3741272
#   Predicted boxes (count): 4 [[78, 0, 89, 5], [111, 0, 127, 19], [13, 9, 114, 127], [106, 26, 114, 47]]
#   Best IoU for this image: 0.0
#
# Processing PID 3b49769a-ae88-4b47-ac0a-92abf3e05f94 | label = 0
#   CAM min/max/mean/std: 0.0 0.995011 0.2761134 0.3296268
#   Using threshold: 0.4409268
#   Predicted boxes (count): 4 [[106, 0, 123, 15], [3, 6, 10, 12], [19, 48, 105, 127], [0, 121, 10, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID d1363e3c-144f-455c-8b72-1e9b3b52bacc | label = 0
#   CAM min/max/mean/std: 0.0 0.99982995 0.43511933 0.35091206
#   Using threshold: 0.6105754
#   Predicted boxes (count): 2 [[118, 3, 127, 11], [13, 25, 114, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID ed98d9bf-2d30-49c3-a6b7-8ac9e893557a | label = 0
#   CAM min/max/mean/std: 0.0 0.9995459 0.35775325 0.36416268
#   Using threshold: 0.5398346
#   Predicted boxes (count): 5 [[39, 0, 74, 40], [84, 0, 91, 4], [116, 5, 124, 10], [13, 16, 110, 127], [100, 17, 111, 31]]
#   Best IoU for this image: 0.0
#
# Processing PID 07125480-e928-4b5c-aaf2-62dddb1bf2a1 | label = 0
#   CAM min/max/mean/std: 0.0 0.96929747 0.2403959 0.24848141
#   Using threshold: 0.3646366
#   Predicted boxes (count): 2 [[0, 2, 12, 16], [12, 53, 111, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID c4d192b9-64a4-455c-94fc-64a874ea451c | label = 0
#   CAM min/max/mean/std: 0.0 0.9598563 0.14504676 0.15553623
#   Using threshold: 0.22281487
#   Predicted boxes (count): 3 [[0, 0, 71, 32], [82, 0, 124, 25], [26, 60, 99, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 69c58f80-97d2-416b-b1fd-f00887b010fb | label = 0
#   CAM min/max/mean/std: 0.0 0.9998839 0.39945728 0.34450167
#   Using threshold: 0.5717081
#   Predicted boxes (count): 3 [[12, 0, 27, 11], [13, 8, 114, 127], [0, 77, 6, 85]]
#   Best IoU for this image: 0.0
#
# Processing PID ab0aa9ce-26ae-47cf-a157-146fa3d90fda | label = 0
#   CAM min/max/mean/std: 0.0 0.9986505 0.27509475 0.32499638
#   Using threshold: 0.43759292
#   Predicted boxes (count): 5 [[3, 2, 9, 10], [116, 3, 125, 10], [12, 22, 33, 88], [104, 22, 114, 55], [12, 40, 115, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 2c810189-ae70-403e-8846-3286925af6dd | label = 0
#   CAM min/max/mean/std: 0.0 0.9996941 0.29071012 0.3659649
#   Using threshold: 0.47369257
#   Predicted boxes (count): 2 [[113, 4, 122, 11], [18, 48, 103, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 83ca4bd1-bd4a-448d-aa84-6b5b07cd037d | label = 0
#   CAM min/max/mean/std: 0.0 0.9997216 0.33407485 0.3631559
#   Using threshold: 0.5156528
#   Predicted boxes (count): 3 [[54, 0, 81, 5], [6, 18, 11, 23], [12, 48, 115, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID e158a4d0-6a35-4d57-8f1a-5670eff19364 | label = 0
#   CAM min/max/mean/std: 0.0 0.96091247 0.20900147 0.20485628
#   Using threshold: 0.31142962
#   Predicted boxes (count): 5 [[0, 0, 12, 10], [42, 0, 80, 8], [108, 0, 127, 16], [14, 18, 18, 41], [13, 27, 110, 127]]
#   Best IoU for this image: 0.0
#
# Processing PID 192748b6-82f2-4f0d-a25d-cea1600c7246 | label = 0
#   CAM min/max/mean/std: 0.0 0.9885011 0.19001323 0.20164114
#   Using threshold: 0.2908338
#   Predicted boxes (count): 2 [[111, 44, 127, 80], [17, 54, 102, 127]]
#   Best IoU for this image: 0.0
#
# Processing P
# 1969   44f76756-0c8b-402b-906d-289f64ca141c       0.0000
# 1970   90b2b94e-efa8-4ff7-98e1-86ea3e33b575       0.2316
# 1971   7307c83f-63e1-46e1-9400-8d1eac241510       0.1324
# 1972   f4ad4e88-ab12-4415-b52b-f372e83b15ef       0.0000
# 1973   43896c75-95f8-49b9-83c2-1ccbc4c159ad       0.0000
# 1974   340b962d-8a45-4593-8728-18b13e26e3b2       0.0000
# 1975   04cdd736-43c8-486a-aa76-9ed39feea7b7       0.0000
# 1976   7108e6d2-d643-42cf-892c-9e15e20e9cbf       0.0000
# 1977   aa60627b-bdea-45a4-ace5-67c64c813020       0.0000
# 1978   f99a905b-e577-42ee-9713-9e82e6663c06       0.0000
# 1979   020a16e3-baf9-4cf0-859c-c79b5253d717       0.0736
# 1980   419f823d-3113-4247-9c63-3bbdc4cc4d45       0.0000
# 1981   0e91afec-c246-450b-9f10-e07a75ae0086       0.0691
# 1982   6bb95d1b-a502-430f-ba27-550549d70de3       0.0000
# 1983   a359f158-12a4-4690-95e6-6d0aa578f2e8       0.0000
# 1984   634dc2f2-faf9-44da-a5f2-011870025110       0.0000
# 1985   ca25855c-546e-4658-aa41-7438615c7554       0.0000
# 1986   a6e6e9be-4ced-4c05-ad59-a07061fe72d6       0.2198
# 1987   3574c226-b39c-48d4-ab38-362c4e52ee82       0.1730
# 1988   646c5605-7233-42a8-b190-0fe199e7d2d4       0.0000
# 1989   34783bc6-c67c-45fc-81ca-202df5b71f38       0.0278
# 1990   8cf2eb4c-fcac-4398-83d1-fba18320cb6f       0.0000
# 1991   48b5f206-d246-4b30-abc1-aa640692fb75       0.0000
# 1992   aabc5401-9f95-456e-913e-6438cc152d00       0.0000
# 1993   eaaee470-cf44-4d79-a5f5-4e8b642fc999       0.0000
# 1994   ebd3762f-46a6-4e1a-9265-33b5598b717c       0.0000
# 1995   53d56991-73ad-4f0c-bd6d-2eab1f84598e       0.0000
# 1996   0456cd35-da6b-459a-8ca6-47af176000c3       0.0000
# 1997   23dde3cd-bdf6-4586-bf6d-8e3306c71455       0.0000
# 1998   263abde3-1556-40de-bf7d-7e523c37c010       0.0000
# 1999   bd0bb326-cd0d-4dd8-be1c-25c15b076377       0.0734
# 2000   71864474-2cba-48f0-8332-003f70bbb9ec       0.0000
# ----------------------------------------------------------
# Mean IoU                                         0.0315
# ===========================================

# %% [markdown]
# ## Step 14 — Check Raw Classifier Predictions
#
# This prints the **softmax probabilities** for a few validation images.
# If all predictions are near `[1, 0]`, the model thinks every image is “Normal”.
# That means you need more training epochs or more positive examples.

# %%
# Quick check of raw classifier outputs on validation set
model.eval()
with torch.no_grad():
    for imgs, labels, pids, _ in val_loader:
        imgs = imgs.to(device)
        outputs, _ = model(imgs)
        probs = F.softmax(outputs, dim=1).cpu().numpy()
        print("Outputs (first batch):", probs[:5])
        break
# Out:
# Outputs (first batch): [[0.8741805  0.12581952]
#  [0.7959416  0.20405842]
#  [0.9095081  0.0904919 ]
#  [0.9784057  0.02159434]
#  [0.91195846 0.08804156]]
